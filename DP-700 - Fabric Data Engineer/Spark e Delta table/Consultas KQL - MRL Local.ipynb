-- %%
-- Welcome to your new notebook
-- Type here in the cell editor to add code!

-- %%
SELECT TOP (10) [SEQLOCAL],
			[NROEMPRESA],
			[LOCAL],
			[TIPLOCAL]
FROM [HML_GL_02].[dbo].[RAW_MRL_LOCAL]
