# %% [markdown]
# # Notebook para realizar DROP em tabelas no Fabric

# %% [markdown]
# ## Verifique qual Lakehouse esta a tabela, e o nome da tabela.

# %%
from pyspark.sql import SparkSession

# Inicialize a sessão do Spark
spark = SparkSession.builder.appName("DropTable").getOrCreate()

# Execute o comando SQL para dropar a tabela
spark.sql("DROP TABLE IF EXISTS Gold_lakehouse_GL.produto_gold")

# Encerre a sessão do Spark
spark.stop()
